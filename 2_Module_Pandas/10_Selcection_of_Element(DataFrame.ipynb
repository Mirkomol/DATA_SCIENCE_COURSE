# %%
import pandas as pd

# %%
uz = {2020:33.5,2019:23.3,2018:32.4,2017:31.9,2016:31.4,2015:30.9}
kz = {2020:18.8,2019:23.3,2018:32.4,2017:31.9,2016:31.4,2015:17.9}
tj = {2020:9.5,2019:23.3,2018:32.4,2017:31.9,2016:31.4,2015:8.9}
kg = {2020:6.5,2019:23.3,2018:32.4,2017:31.9,2016:31.4,2015:6.9}
tr = {2020:6.0,2019:5.8,2018:32.4,2017:31.9,2016:31.4,2015:5.6}


df = pd.DataFrame(
{
    'Uzbekistan':uz,
    'Kazhaksatan':kz,
    'Tajikistan':tj,
    'Kyrgizstan':kg,
    'Turkmenistan':tr
})

# %%
df
# Out:
#       Uzbekistan  Kazhaksatan  Tajikistan  Kyrgizstan  Turkmenistan
# 2020        33.5         18.8         9.5         6.5           6.0
# 2019        23.3         23.3        23.3        23.3           5.8
# 2018        32.4         32.4        32.4        32.4          32.4
# 2017        31.9         31.9        31.9        31.9          31.9
# 2016        31.4         31.4        31.4        31.4          31.4
# 2015        30.9         17.9         8.9         6.9           5.6

# %%
df['Uzbekistan'].to_numpy()
# Out:
# array([33.5, 23.3, 32.4, 31.9, 31.4, 30.9])

# %%
df[['Uzbekistan','Turkmenistan']]
# Out:
#       Uzbekistan  Turkmenistan
# 2020        33.5           6.0
# 2019        23.3           5.8
# 2018        32.4          32.4
# 2017        31.9          31.9
# 2016        31.4          31.4
# 2015        30.9           5.6

# %%
df[3:]
# Out:
#       Uzbekistan  Kazhaksatan  Tajikistan  Kyrgizstan  Turkmenistan
# 2017        31.9         31.9        31.9        31.9          31.9
# 2016        31.4         31.4        31.4        31.4          31.4
# 2015        30.9         17.9         8.9         6.9           5.6

# %%
df
# Out:
#       Uzbekistan  Kazhaksatan  Tajikistan  Kyrgizstan  Turkmenistan
# 2020        33.5         18.8         9.5         6.5           6.0
# 2019        23.3         23.3        23.3        23.3           5.8
# 2018        32.4         32.4        32.4        32.4          32.4
# 2017        31.9         31.9        31.9        31.9          31.9
# 2016        31.4         31.4        31.4        31.4          31.4
# 2015        30.9         17.9         8.9         6.9           5.6

# %%
df>10
# Out:
#       Uzbekistan  Kazhaksatan  Tajikistan  Kyrgizstan  Turkmenistan
# 2020        True         True       False       False         False
# 2019        True         True        True        True         False
# 2018        True         True        True        True          True
# 2017        True         True        True        True          True
# 2016        True         True        True        True          True
# 2015        True         True       False       False         False

# %%
df >7
# Out:
#       Uzbekistan  Kazhaksatan  Tajikistan  Kyrgizstan  Turkmenistan
# 2020        True         True        True       False         False
# 2019        True         True        True        True         False
# 2018        True         True        True        True          True
# 2017        True         True        True        True          True
# 2016        True         True        True        True          True
# 2015        True         True        True       False         False

# %%
df > 6.3
# Out:
#       Uzbekistan  Kazhaksatan  Tajikistan  Kyrgizstan  Turkmenistan
# 2020        True         True        True        True         False
# 2019        True         True        True        True         False
# 2018        True         True        True        True          True
# 2017        True         True        True        True          True
# 2016        True         True        True        True          True
# 2015        True         True        True        True         False

# %%
df[['Uzbekistan']][df['Uzbekistan']>32] # values more than 32
# Out:
#       Uzbekistan
# 2020        33.5
# 2018        32.4

# %%
dfuz = df[['Uzbekistan']]

# %%
dfuz[dfuz['Uzbekistan']>32]
# Out:
#       Uzbekistan
# 2020        33.5
# 2018        32.4

# %%
df
# Out:
#       Uzbekistan  Kazhaksatan  Tajikistan  Kyrgizstan  Turkmenistan
# 2020        33.5         18.8         9.5         6.5           6.0
# 2019        23.3         23.3        23.3        23.3           5.8
# 2018        32.4         32.4        32.4        32.4          32.4
# 2017        31.9         31.9        31.9        31.9          31.9
# 2016        31.4         31.4        31.4        31.4          31.4
# 2015        30.9         17.9         8.9         6.9           5.6

# %%
df2 = df.transpose(copy = True)

# %%
df2
# Out:
#               2020  2019  2018  2017  2016  2015
# Uzbekistan    33.5  23.3  32.4  31.9  31.4  30.9
# Kazhaksatan   18.8  23.3  32.4  31.9  31.4  17.9
# Tajikistan     9.5  23.3  32.4  31.9  31.4   8.9
# Kyrgizstan     6.5  23.3  32.4  31.9  31.4   6.9
# Turkmenistan   6.0   5.8  32.4  31.9  31.4   5.6

# %%
df2[df2[2015]>6]
# Out:
#              2020  2019  2018  2017  2016  2015
# Uzbekistan   33.5  23.3  32.4  31.9  31.4  30.9
# Kazhaksatan  18.8  23.3  32.4  31.9  31.4  17.9
# Tajikistan    9.5  23.3  32.4  31.9  31.4   8.9
# Kyrgizstan    6.5  23.3  32.4  31.9  31.4   6.9

# %%
df2[df2[2015]<8]
# Out:
#               2020  2019  2018  2017  2016  2015
# Kyrgizstan     6.5  23.3  32.4  31.9  31.4   6.9
# Turkmenistan   6.0   5.8  32.4  31.9  31.4   5.6
