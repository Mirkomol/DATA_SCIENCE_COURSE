# %%
import pandas as pd

# %%
import numpy as np

# %%
tashkent = pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %%
tashkent
# Out:
# [           Tashkent  Uzbek: Toshkent Russian: Ташкент  \
#  0                                             Capital
#  1                                            Toshkent
#  2   .mw-parser-output .tmulti .thumbinner{display:...
#  3   .mw-parser-output .ib-settlement-cols{text-ali...
#  4                          Nickname(s): Tash (A rock)
#  5   Motto(s): Kuch Adolatdadir!("Strength is in Ju...
#  6   .mw-parser-output .locmap .od{position:absolut...
#  7   Coordinates: .mw-parser-output .geo-default,.m...
#  8                                             Country
#  9                                             Settled
#  10                                         Government
#  11                                             • Type
#  12                                    • Hakim (Mayor)
#  13                                               Area
#  14                                            • Total
#  15                                          Elevation
# ...

# %%
len(tashkent)
# Out:
# 17

# %%
tashkent[0]
# Out:
#            Tashkent  Uzbek: Toshkent Russian: Ташкент  \
# 0                                             Capital
# 1                                            Toshkent
# 2   .mw-parser-output .tmulti .thumbinner{display:...
# 3   .mw-parser-output .ib-settlement-cols{text-ali...
# 4                          Nickname(s): Tash (A rock)
# 5   Motto(s): Kuch Adolatdadir!("Strength is in Ju...
# 6   .mw-parser-output .locmap .od{position:absolut...
# 7   Coordinates: .mw-parser-output .geo-default,.m...
# 8                                             Country
# 9                                             Settled
# 10                                         Government
# 11                                             • Type
# 12                                    • Hakim (Mayor)
# 13                                               Area
# 14                                            • Total
# 15                                          Elevation
# ...

# %%
tashkent[6]
# Out:
#                                                     0  \
# 0   YearPop.±% p.a.1897 155,673— 1959 911,930+2.89...
# 1                                                Year
# 2                                                1897
# 3                                                1959
# 4                                                1970
# 5                                                1979
# 6                                                1983
# 7                                                1989
# 8                                                1991
# 9                                                1995
# 10                                               2000
# 11                                               2001
# 12                                               2002
# 13                                               2003
# 14                                               2004
# 15                                               2005
# ...

# %%
tashkent[10]
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteTashkent  \
# 0                                                NaN
# 1                                                NaN
# 2                                    Tashkent portal
#
# ...
