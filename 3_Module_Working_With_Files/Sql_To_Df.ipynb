# %%
import pandas as pd

# %%
import sqlite3 as sql

# %%
import pprint as pprint

# %%
db = sql.connect("chinook.db")

# %%
cursor = db.cursor()

# %%
cursor.execute("SELECT * FROM customers; ")
customers = cursor.fetchall()

# %%
df = pd.read_sql("SELECT * FROM customers LIMIT 10; ",db, index_col = 'CustomerId')

# %%
df
# Out:
#             FirstName     LastName  \
# CustomerId
# 1                Luís    Gonçalves
# 2              Leonie       Köhler
# 3            François     Tremblay
# 4               Bjørn       Hansen
# 5           František  Wichterlová
# 6              Helena         Holý
# 7              Astrid       Gruber
# 8                Daan      Peeters
# 9                Kara      Nielsen
# 10            Eduardo      Martins
#
#                                                      Company  \
# CustomerId
# 1           Embraer - Empresa Brasileira de Aeronáutica S.A.
# 2                                                       None
# 3                                                       None
# 4                                                       None
# 5                                           JetBrains s.r.o.
# 6                                                       None
# 7                                                       None
# ...

# %%
df = pd.read_sql("SELECT * FROM artists ; ",db, index_col = 'ArtistId')

# %%
df
# Out:
#                                                        Name
# ArtistId
# 1                                                     AC/DC
# 2                                                    Accept
# 3                                                 Aerosmith
# 4                                         Alanis Morissette
# 5                                           Alice In Chains
# ...                                                     ...
# 271        Mela Tenenbaum, Pro Musica Prague & Richard Kapp
# 272                                  Emerson String Quartet
# 273       C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 274                                           Nash Ensemble
# 275                                   Philip Glass Ensemble
#
# [275 rows x 1 columns]

# %%
df = pd.read_sql("SELECT CustomerId,Firstname,Lastname,Phone FROM customers ; ",db, index_col = 'CustomerId')

# %%
df.head()
# Out:
#             FirstName     LastName               Phone
# CustomerId
# 1                Luís    Gonçalves  +55 (12) 3923-5555
# 2              Leonie       Köhler    +49 0711 2842222
# 3            François     Tremblay   +1 (514) 721-4711
# 4               Bjørn       Hansen     +47 22 44 22 22
# 5           František  Wichterlová    +420 2 4172 5555
