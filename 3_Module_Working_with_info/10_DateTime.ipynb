# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
df= pd.read_csv("database.csv")

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
#  13  Horizontal Distance         1604 non-null   float64
#  14  Horizontal Error            1156 non-null   float64
#  15  Root Mean Square            17352 non-null  float64
#  16  ID                          23412 non-null  object
#  17  Source                      23412 non-null  object
#  18  Location Source             23412 non-null  object
#  19  Magnitude Source            23412 non-null  object
#  20  Status                      23412 non-null  object
# dtypes: float64(12), object(9)
# memory usage: 3.8+ MB

# %%
sana = df.at[0,'Date']

# %%
sana
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-6df3e49b9a41> in <module>
# ----> 1 sana.now
#
# AttributeError: 'str' object has no attribute 'now'

# %%
pd.to_datetime(df['Date'],format='\m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-4804e913d504> in <module>
# ----> 1 pd.to_datetime(df['Date'],format='\m/%d/%Y')
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     881                 result = result.tz_localize(tz)  # type: ignore[call-arg]
#     882     elif isinstance(arg, ABCSeries):
# --> 883         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     884         if not cache_array.empty:
#     885             result = arg.map(cache_array)
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     193         unique_dates = unique(arg)
#     194         if len(unique_dates) < len(arg):
# --> 195             cache_dates = convert_listlike(unique_dates, format)
#     196             cache_array = Series(cache_dates, index=unique_dates)
#     197             # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     391
#     392     if format is not None:
# --> 393         res = _to_datetime_with_format(
#     394             arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     395         )
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     511             return DatetimeIndex._simple_new(dta, name=name)
#     512         except (ValueError, TypeError):
# --> 513             raise err
#     514
#     515
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     498
#     499         # fallback
# --> 500         res = _array_strptime_with_fallback(
#     501             arg, name, tz, fmt, exact, errors, infer_datetime_format
#     502         )
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434
#     435     try:
# --> 436         result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     437         if "%Z" in fmt or "%z" in fmt:
#     438             return _return_parsed_timezone_results(result, timezones, tz, name)
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '01/02/1965' does not match format '\m/%d/%Y' (match)

# %%
# dinsing length
df['Date'].str.len().value_countsts()
# Out:
# 10    23409
# 24        3
# Name: Date, dtype: int64

# %%
# finding lenght of more than 10
df[df['Date'].str.len() == 24]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Latitude, Longitude, Type, Depth, Depth Error, Depth Seismic Stations, Magnitude, Magnitude Type, Magnitude Error, Magnitude Seismic Stations, Azimuthal Gap, Horizontal Distance, Horizontal Error, Root Mean Square, ID, Source, Location Source, Magnitude Source, Status]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.loc[3378,'Date'] = '02/23/1975'

# %%
df.loc[7512, 'Date'] = '02/23/1975'
df.loc[20650, 'Date'] = '02/23/1975'

# %%
df['datetime'] = pd.to_datetime(df['Date'],format='%m/%d/%Y')

# %%
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0              NaN                     NaN        6.0             MW  ...
# 1              NaN                     NaN        5.8             MW  ...
# 2              NaN                     NaN        6.2             MW  ...
# 3              NaN                     NaN        5.8             MW  ...
# 4              NaN                     NaN        5.8             MW  ...
# ...            ...                     ...        ...            ...  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# 0                NaN                  NaN               NaN               NaN
# 1                NaN                  NaN               NaN               NaN
# 2                NaN                  NaN               NaN               NaN
# 3                NaN                  NaN               NaN               NaN
# 4                NaN                  NaN               NaN               NaN
# ...              ...                  ...               ...               ...
# 23407          42.47                0.120               NaN            0.1898
# 23408          48.58                0.129               NaN            0.2187
# 23409          91.00                0.992               4.8            1.5200
# 23410          26.00                3.553               6.0            1.4300
# 23411          97.00                0.681               4.5            0.9100
#
#                  ID  Source Location Source Magnitude Source     Status  \
# 0      ISCGEM860706  ISCGEM          ISCGEM           ISCGEM  Automatic
# 1      ISCGEM860737  ISCGEM          ISCGEM           ISCGEM  Automatic
# 2      ISCGEM860762  ISCGEM          ISCGEM           ISCGEM  Automatic
# 3      ISCGEM860856  ISCGEM          ISCGEM           ISCGEM  Automatic
# 4      ISCGEM860890  ISCGEM          ISCGEM           ISCGEM  Automatic
# ...             ...     ...             ...              ...        ...
# 23407    NN00570710      NN              NN               NN   Reviewed
# 23408    NN00570744      NN              NN               NN   Reviewed
# 23409    US10007NAF      US              US               US   Reviewed
# 23410    US10007NL0      US              US               US   Reviewed
# 23411    US10007NTD      US              US               US   Reviewed
#
#         datetime
# 0     1965-01-02
# 1     1965-01-04
# 2     1965-01-05
# 3     1965-01-08
# 4     1965-01-09
# ...          ...
# 23407 2016-12-28
# 23408 2016-12-28
# 23409 2016-12-28
# 23410 2016-12-29
# 23411 2016-12-30
#
# [23412 rows x 22 columns]

# %% [markdown]
# # Working datetime

# %%
df.at[0,'datetime'].weekday()
# Out:
# 5

# %%
df['month']=df['datetime'].dt.month

# %%
df['month'].value_counts()
# Out:
# 3     2113
# 8     2014
# 12    2001
# 11    1987
# 9     1985
# 4     1970
# 5     1964
# 10    1952
# 1     1891
# 7     1880
# 2     1831
# 6     1824
# Name: month, dtype: int64

# %%
df['weekday']=df['datetime'].dt.weekday

# %%
df['time'] = pd.to_datetime(df['Time'],format='%H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-d43b2592d462> in <module>
# ----> 1 df['time'] = pd.to_datetime(df['Time'],format='%H:%M:%S')
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     885             result = arg.map(cache_array)
#     886         else:
# --> 887             values = convert_listlike(arg._values, format)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     391
#     392     if format is not None:
# --> 393         res = _to_datetime_with_format(
#     394             arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     395         )
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     511             return DatetimeIndex._simple_new(dta, name=name)
#     512         except (ValueError, TypeError):
# --> 513             raise err
#     514
#     515
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     498
#     499         # fallback
# --> 500         res = _array_strptime_with_fallback(
#     501             arg, name, tz, fmt, exact, errors, infer_datetime_format
#     502         )
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\core\tools\datetimes.py in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434
#     435     try:
# --> 436         result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     437         if "%Z" in fmt or "%z" in fmt:
#     438             return _return_parsed_timezone_results(result, timezones, tz, name)
#
# c:\users\ultrashopuz\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '1975-02-23T02:58:41.000Z' does not match format '%H:%M:%S' (match)

# %%
df['Time'].str.len().value_counts()
# Out:
# 8     23409
# 24        3
# Name: Time, dtype: int64

# %%
df[df['Time'].str.len()==24]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Latitude, Longitude, Type, Depth, Depth Error, Depth Seismic Stations, Magnitude, Magnitude Type, Magnitude Error, Magnitude Seismic Stations, Azimuthal Gap, Horizontal Distance, Horizontal Error, Root Mean Square, ID, Source, Location Source, Magnitude Source, Status, datetime, month, weekday]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.loc[20650,'Time'] = '12:14:20'
