# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("praktikum_datasets/automobile_data_nan.csv",index_col=0)

# %%
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df.fillna(0) # standard parameter not recomendde just for comffort
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         0.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         0.0   171.7           0
# 86      volkswagen        sedan        97.3     0.0         ohc
# 87           volvo        sedan       104.3   188.8           0
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         0.0             21.0  13495.0
# ...

# %%
df.fillna(777)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible       777.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan       777.0   171.7         777
# 86      volkswagen        sedan        97.3   777.0         ohc
# 87           volvo        sedan       104.3   188.8         777
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       777.0             21.0  13495.0
# ...

# %%
# with col
df.fillna({'horsepower':100,'wheel-base':90}) # filling each column
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        90.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        90.0   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       100.0             21.0  13495.0
# ...

# %%
#avg
avgwhell=np.mean(df['horsepower'])

# %%
df.fillna({'horsepower':avgwhell,'wheel-base':90})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        90.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        90.0   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four  108.266667             21.0  13495.0
# ...

# %%
df.fillna(method ='ffill') # forward filler
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df.fillna(method = 'bfill') # next or backward
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        94.5   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   188.8         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       111.0             21.0  13495.0
# ...

# %%
df[df.company=='toyota'].fillna(method='bfill')
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67           62.0             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71          156.0             27.0   8778.0
# 79          156.0              NaN  15750.0

# %%
df[df.company=='toyota']=df[df.company=='toyota'].fillna(method='bfill')

# %%
df[df.company=='toyota']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67           62.0             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71          156.0             27.0   8778.0
# 79          156.0              NaN  15750.0

# %%
df.fillna(df.mean()) # fill empty with average
# Out:
# <ipython-input-26-a2478f315f9e>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#            company   body-style  wheel-base      length engine-type  \
# index
# 0      alfa-romero  convertible   88.600000  168.800000        dohc
# 1      alfa-romero  convertible   99.072917  168.800000        dohc
# 2      alfa-romero    hatchback   94.500000  171.200000        ohcv
# 3             audi        sedan   99.800000  176.600000         ohc
# 4             audi        sedan   99.400000  176.600000         ohc
# ...            ...          ...         ...         ...         ...
# 81      volkswagen        sedan   97.300000  171.700000         ohc
# 82      volkswagen        sedan   99.072917  171.700000         NaN
# 86      volkswagen        sedan   97.300000  173.767347         ohc
# ...

# %%
dfh = df[df['body-style']=='hatchback']

# %%
dfh.fillna(dfh.mean)
# Out:
#            company body-style  \
# index
# 2      alfa-romero  hatchback
# 16       chevrolet  hatchback
# 17       chevrolet  hatchback
# 19           dodge  hatchback
# 20           dodge  hatchback
# 36           mazda  hatchback
# 37           mazda  hatchback
# 38           mazda  hatchback
# 39           mazda  hatchback
# 49      mitsubishi  hatchback
# 50      mitsubishi  hatchback
# 63         porsche  hatchback
# 66          toyota  hatchback
# 67          toyota  hatchback
# 68          toyota  hatchback
#
#                                               wheel-base  \
# index
# 2                                                   94.5
# 16                                                  88.4
# 17                                                  94.5
# 19                                                  93.7
# 20                                                  93.7
# 36                                                  93.1
# ...
