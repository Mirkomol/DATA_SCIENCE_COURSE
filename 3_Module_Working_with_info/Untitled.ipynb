# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/melb_data.csv?raw=true")
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
df['YearBuilt'].isna().sum()
# Out:
# 5344

# %%
df.isna()==0
# Out:
#        Suburb  Address  Rooms  Type  Price  Method  SellerG  Date  Distance  \
# 0        True     True   True  True   True    True     True  True      True
# 1        True     True   True  True   True    True     True  True      True
# 2        True     True   True  True   True    True     True  True      True
# 3        True     True   True  True   True    True     True  True      True
# 4        True     True   True  True   True    True     True  True      True
# ...       ...      ...    ...   ...    ...     ...      ...   ...       ...
# 13513    True     True   True  True   True    True     True  True      True
# 13514    True     True   True  True   True    True     True  True      True
# 13515    True     True   True  True   True    True     True  True      True
# 13516    True     True   True  True   True    True     True  True      True
# 13517    True     True   True  True   True    True     True  True      True
#
#        Postcode  ...  Bathroom   Car  Landsize  BuildingArea  YearBuilt  \
# 0          True  ...      True  True      True         False      False
# 1          True  ...      True  True      True          True       True
# 2          True  ...      True  True      True          True       True
# 3          True  ...      True  True      True         False      False
# 4          True  ...      True  True      True          True       True
# ...         ...  ...       ...   ...       ...           ...        ...
# 13513      True  ...      True  True      True         False       True
# 13514      True  ...      True  True      True          True       True
# 13515      True  ...      True  True      True         False       True
# 13516      True  ...      True  True      True          True       True
# 13517      True  ...      True  True      True          True       True
#
#        CouncilArea  Lattitude  Longtitude  Regionname  Propertycount
# 0             True       True        True        True           True
# 1             True       True        True        True           True
# 2             True       True        True        True           True
# 3             True       True        True        True           True
# 4             True       True        True        True           True
# ...            ...        ...         ...         ...            ...
# 13513        False       True        True        True           True
# 13514        False       True        True        True           True
# 13515        False       True        True        True           True
# 13516        False       True        True        True           True
# 13517        False       True        True        True           True
#
# [13518 rows x 21 columns]

# %%
df[df['YearBuilt'] == 'Northern Metropolitan']
# Out:
# Empty DataFrame
# Columns: [Suburb, Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bedroom2, Bathroom, Car, Landsize, BuildingArea, YearBuilt, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount]
# Index: []
#
# [0 rows x 21 columns]

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13513  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13514   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13515   Williamstown       83 Power St      3    h  1170000.0      S
# 13516   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13517     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13513     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13514  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13515     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13516   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13517   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13513           NaN     1981.0          NaN -37.90562   145.16761
# 13514         133.0     1995.0          NaN -37.85927   144.87904
# 13515           NaN     1997.0          NaN -37.85274   144.88738
# 13516         157.0     1920.0          NaN -37.85908   144.89299
# 13517         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13513  South-Eastern Metropolitan        7392.0
# 13514        Western Metropolitan        6380.0
# 13515        Western Metropolitan        6380.0
# 13516        Western Metropolitan        6380.0
# 13517        Western Metropolitan        6543.0
#
# [13518 rows x 21 columns]

# %%
a = df[df['Rooms']==5]

# %%
a
# Out:
#                   Suburb         Address  Rooms Type      Price Method  \
# 55          Airport West    241 Parer Rd      5    h   755000.0     PI
# 93           Albert Park    23 Finlay St      5    h  2100000.0      S
# 124           Alphington    83 Fulham Rd      5    h  2840000.0      S
# 142               Altona   59 Bracken Gr      5    h  1525000.0      S
# 186         Altona North     45 Hearn St      5    h  1085000.0      S
# ...                  ...             ...    ...  ...        ...    ...
# 13401             Keilor     16 Kiewa Cr      5    h   739000.0      S
# 13411                Kew   16 Hodgson St      5    h  3450000.0     PI
# 13430             Melton   21D Yuille St      5    h   710000.0     PI
# 13498  Templestowe Lower  50 Caroline Dr      5    h  1400000.0      S
# 13505           Viewbank   149 Graham Rd      5    h  1316000.0     SP
#
#           SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 55     Propertyau  14/05/2016      13.5    3042.0  ...       2.0  2.0
# 93           Greg  10/12/2016       3.3    3206.0  ...       2.0  1.0
# 124        Nelson  12/06/2016       6.4    3078.0  ...       4.0  4.0
# 142          Greg   3/12/2016      13.8    3018.0  ...       3.0  3.0
# 186            FN   3/09/2016      11.1    3025.0  ...       3.0  6.0
# ...           ...         ...       ...       ...  ...       ...  ...
# 13401      Daniel  26/08/2017      14.5    3036.0  ...       2.0  2.0
# 13411         Kay  26/08/2017       5.4    3101.0  ...       2.0  2.0
# 13430       Ryder  26/08/2017      31.7    3337.0  ...       2.0  2.0
# 13498       Barry  26/08/2017      12.4    3107.0  ...       3.0  2.0
# 13505      Nelson  26/08/2017       8.9    3084.0  ...       3.0  3.0
#
#        Landsize  BuildingArea  YearBuilt    CouncilArea Lattitude  Longtitude  \
# 55        596.0           NaN        NaN  Moonee Valley -37.72480   144.86990
# 93        237.0           NaN        NaN   Port Phillip -37.84360   144.95570
# 124       809.0         165.0     1910.0        Darebin -37.77500   145.02680
# 142       729.0         268.0     2005.0    Hobsons Bay -37.87210   144.81050
# 186       592.0         251.0     1965.0    Hobsons Bay -37.83880   144.85670
# ...         ...           ...        ...            ...       ...         ...
# 13401     295.0           NaN        NaN            NaN -37.71945   144.82418
# 13411     668.0           0.0     2006.0            NaN -37.80795   145.01474
# 13430    1670.0         280.0     2000.0            NaN -37.67813   144.59292
# 13498     717.0         310.0     1963.0            NaN -37.76630   145.11320
# 13505     696.0           NaN        NaN            NaN -37.73501   145.08341
#
#                   Regionname Propertycount
# 55      Western Metropolitan        3464.0
# 93     Southern Metropolitan        3280.0
# 124    Northern Metropolitan        2211.0
# 142     Western Metropolitan        5301.0
# 186     Western Metropolitan        5132.0
# ...                      ...           ...
# 13401   Western Metropolitan        2339.0
# 13411  Southern Metropolitan       10331.0
# 13430       Western Victoria        3600.0
# 13498   Eastern Metropolitan        5420.0
# 13505   Eastern Metropolitan        2698.0
#
# [596 rows x 21 columns]

# %%
a['BuildingArea'].sum()
# Out:
# 141151.3567

# %%
a = df[df['Rooms']==10]

# %%
a
# Out:
#          Suburb    Address  Rooms Type     Price Method SellerG        Date  \
# 11304  Bundoora  5 Ball Ct     10    h  900000.0     PI     Ray  15/07/2017
#
#        Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 11304      12.1    3083.0  ...       3.0  2.0     313.0           NaN
#
#        YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 11304     2006.0      Darebin -37.71098   145.05381  Northern Metropolitan
#
#       Propertycount
# 11304       10175.0
#
# [1 rows x 21 columns]
