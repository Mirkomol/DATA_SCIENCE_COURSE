# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("praktikum_datasets/museum_visitors.csv",index_col = 0)

# %%
df.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
df.shape
# Out:
# (59, 4)

# %%
sns.lineplot(data=df)
plt.show()

# %%
plt.plot(df)
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.title("Muzeyl visitors")
plt.xlabel("Sana")
plt.xticks(rotation=90)
plt.ylabel("QUantity of People")
sns.lineplot(data=df['Firehouse Museum'])
plt.grid()
plt.show()
